# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhimanyuAryan/CamVidSegmentation/blob/master/Image_Segmentation_with_CamVid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [PosixPath('/content/data/camvid/images'),
#  PosixPath('/content/data/camvid/valid.txt'),
#  PosixPath('/content/data/camvid/codes.txt'),
#  PosixPath('/content/data/camvid/labels')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# # Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/content/data/camvid/images/0001TP_010350.png'),
#  PosixPath('/content/data/camvid/images/0016E5_01980.png'),
#  PosixPath('/content/data/camvid/images/0016E5_00390.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/content/data/camvid/labels/0001TP_008850_P.png'),
#  PosixPath('/content/data/camvid/labels/0006R0_f01140_P.png'),
#  PosixPath('/content/data/camvid/labels/0001TP_009000_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-f451ba1ac116> in <module>()
#       1 img_f = fnames[0]
#       2 img = open_image(img_f)
# ----> 3 img.show(figsize=(5,5))
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/image.py in show(self, ax, figsize, title, hide_axis, cmap, y, **kwargs)
#     218         "Show image on `ax` with `title`, using `cmap` if single-channel, overlaid with optional `y`"
#     219         cmap = ifnone(cmap, defaults.cmap)
# --> 220         ax = show_image(self, ax=ax, hide_axis=hide_axis, cmap=cmap, figsize=figsize)
#     221         if y is not None: y.show(ax=ax, **kwargs)
#     222         if title is not None: ax.set_title(title)
#
# /usr/local/lib/python3.6/dist-packages/fastai/vision/image.py in show_image(img, ax, figsize, hide_axis, cmap, alpha, **kwargs)
# ...

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
open_mask??

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[21, 21, 21,  ..., 26, 26, 26],
#           [21, 21, 21,  ..., 26, 26, 26],
#           [21, 21, 21,  ..., 26, 26, 26],
#           ...,
#           [17, 17, 17,  ..., 17, 17, 17],
#           [17, 17, 17,  ..., 17, 17, 17],
#           [17, 17, 17,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ### DataSets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## MODEL

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:00, 88391987.53it/s]

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# Total time: 34:26 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.333747</td>
#       <td>0.866325</td>
#       <td>0.811868</td>
#       <td>03:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.850614</td>
#       <td>0.608044</td>
#       <td>0.837257</td>
#       <td>03:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.714624</td>
#       <td>0.565478</td>
#       <td>0.855253</td>
#       <td>03:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.643406</td>
#       <td>0.559985</td>
#       <td>0.859738</td>
#       <td>03:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.614329</td>
#       <td>0.491420</td>
#       <td>0.866242</td>
#       <td>03:25</td>
#     </tr>
# ...

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# Total time: 42:31 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.384668</td>
#       <td>0.337470</td>
#       <td>0.897584</td>
#       <td>03:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.374887</td>
#       <td>0.326650</td>
#       <td>0.900896</td>
#       <td>03:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.367035</td>
#       <td>0.314243</td>
#       <td>0.906110</td>
#       <td>03:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.358455</td>
#       <td>0.323275</td>
#       <td>0.906805</td>
#       <td>03:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.351376</td>
#       <td>0.310229</td>
#       <td>0.913930</td>
#       <td>03:32</td>
#     </tr>
# ...

# %%
learn.save('stage-1-big')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec216fcf461f> in <module>()
# ----> 1 learn.save('stage-1-big')
#
# NameError: name 'learn' is not defined

# %%
learn.load('stage-1-big');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-83a4323fd8fa> in <module>()
# ----> 1 learn.load('stage-1-big');
#
# NameError: name 'learn' is not defined

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3be9d91d4181> in <module>()
# ----> 1 lrs = slice(1e-6,lr/10)
#
# NameError: name 'lr' is not defined

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-253b44928e5b> in <module>()
# ----> 1 learn.fit_one_cycle(10, lrs)
#
# NameError: name 'learn' is not defined

# %%
learn.save('stage-2-big')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-255edd4a0af1> in <module>()
# ----> 1 learn.save('stage-2-big')
#
# NameError: name 'learn' is not defined

# %%
learn.load('stage-2-big');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cc9674decc22> in <module>()
# ----> 1 learn.load('stage-2-big');
#
# NameError: name 'learn' is not defined

# %%
learn.show_results(rows=3, figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-794defc0ac78> in <module>()
# ----> 1 learn.show_results(rows=3, figsize=(10,10))
#
# NameError: name 'learn' is not defined
